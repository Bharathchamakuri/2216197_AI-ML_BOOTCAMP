# %% [markdown]
# # New section

# %%
#1.Implement the methods of strings with examples.

#strings
str="AI ML Bootcamp"
print(str[0])
print(str[-2])

#slicing
print(str[0:7])

#from:to(n-1):3
print(str[0:5:3])

#reverse of string
print(str[::-1])

#string methods
string="i am learning python programming language"
print(string.upper())
print(string.lower())
print(string.swapcase())
print(string.lstrip())

#string operations
str1="python"
str2="programming"
print(str1+str2)
print(str1*2)
print(str1+str1)

#Comparing string
str1 = "i want to learn coding"
str2 = "I am learning Python"
print(str1==str2)
# Out:
# A
# m
# AI ML B
# AM
# pmactooB LM IA
# I AM LEARNING PYTHON PROGRAMMING LANGUAGE
# i am learning python programming language
# I AM LEARNING PYTHON PROGRAMMING LANGUAGE
# i am learning python programming language
# pythonprogramming
# pythonpython
# pythonpython
# False

# %%
#2.Implement the methods of list with examples

#lists
list1=[10,98,21,78]
list2=[12,"python","5.2"]
list3=["AI","ML","Bootcamp"]

#indexing
print(list1[2])
print(list1[-3])

#slicing
print(list1[:5])

#nested list
list4=["coding",list1,list2]
print(list4[0][0:6])
print(list4[2][1:2][0][0])

#list method
list1.append(76)
print(list1)

l1=[41,23,53,94,72,36,24,49,61,48,41]

print(l1.count(4))
print(len(l1))
print(l1[::-1])
l1.sort()
print(l1)
# Out:
# 21
# 98
# [10, 98, 21, 78]
# coding
# p
# [10, 98, 21, 78, 76]
# 0
# 11
# [41, 48, 61, 49, 24, 36, 72, 94, 53, 23, 41]
# [23, 24, 36, 41, 41, 48, 49, 53, 61, 72, 94]

# %%
#3.Implement methods of tuples with examples.

#Tuples
tup1=(11,23,34,45)
tup2=("Bharath",1.1,5)
tup3=("python",tup1,tup2)
print(tup3[-1][-1])

#tuple methods
print(tup1.count(1))
print(tup1.index(23))
print(max(tup1))
print(min(tup1))
print(tup1[2:6])
print(tup1[:-5])
print(tup1[5:])
print(tup1[:])
# Out:
# 5
# 0
# 1
# 45
# 11
# (34, 45)
# ()
# ()
# (11, 23, 34, 45)

# %%
#4.Implement the methods of dictionary with examples.
#dictionaries
dict1={'name':'Bharath',212:'English'}
print(dict1['name'])
print(dict1.keys())
print(dict1.values())
print(dict1.get("name"))

Items_list = {1: "Apple", 2: "Banana", 3: "Orange"}
print(Items_list)
del Items_list[1]
print(Items_list)
# Out:
# Bharath
# dict_keys(['name', 212])
# dict_values(['Bharath', 'English'])
# Bharath
# {1: 'Apple', 2: 'Banana', 3: 'Orange'}
# {2: 'Banana', 3: 'Orange'}

# %%
#5.Implement the methods of sets with examples.
#sets
set1={33,12,33,44}
set2={3,2.4,"hello"}

list1=[11,21,77,55]
print(list1)
set3=set(list1)
print(set3)
#set methods
set1.add(55)
print(set1)

set2.update([5,6])
print(set2)

set1.discard(11)
print(set1)

list2=list(set1)
print(list2)

#set operation
c={11,22,33,44}
d={44,55,66,77}

#union
print(c|d)
print(c.union(d))
print(d.union(c))

#intersection
print(c&d)
print(c.intersection(d))
print(d.intersection(c))

#difference
print(c-d)
print(c.difference(d))
print(d-c)
print(d.difference(c))
# Out:
# [11, 21, 77, 55]
# {11, 77, 21, 55}
# {33, 12, 44, 55}
# {2.4, 3, 5, 6, 'hello'}
# {33, 12, 44, 55}
# [33, 12, 44, 55]
# {33, 66, 11, 44, 77, 22, 55}
# {33, 66, 11, 44, 77, 22, 55}
# {33, 66, 11, 44, 77, 22, 55}
# {44}
# {44}
# {44}
# {33, 11, 22}
# {33, 11, 22}
# {66, 77, 55}
# {66, 77, 55}

# %%
#6.Write a python program to convert decimal to binary,octal to hexadecimal with direct method. 

dec = 143
print("The decimal value of", dec, "is:")
print(bin(dec), "in binary.")
print(oct(dec), "in octal.")
print(hex(dec), "in hexadecimal.")
# Out:
# The decimal value of 143 is:
# 0b10001111 in binary.
# 0o217 in octal.
# 0x8f in hexadecimal.

# %%
#7.Implement arithmetic operators with examples.
#operators
#arithmetic operators
print("arithmetic operators")
a=36
b=6
print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# arithmetic operators
# 42
# 30
# 216
# 2176782336
# 6.0
# 6
# 0

# %%
#8.Implement assignment operator with examples.
#assignment operator
a=36
b=6
c=a+b
print(c)
c-=a
print(c)
c+=a
print(c)
c-=b
print(c)
c+=b
print(c)
# Out:
# 42
# 6
# 42
# 36
# 42

# %%
#9.Implement comparision operator with examples.
#comparsion operateor
a=32
b=55
a>=b
print(a)
a==b
print(a)
a<=b
print(a)
a<<b
print(a)
a>>b
print(a)
a!=b
print(a)
# Out:
# 32
# 32
# 32
# 32
# 32
# 32

# %%
#10.Implement logical operators with examples.
#logical operators
a=False
b=True
print("a and b is",a and b)
print("a or b is",a or b)
print("a not b is",not b)
# Out:
#   File "<ipython-input-19-ac4150c425e1>", line 7
#     print("a not b is",not b)
#                            ^
# SyntaxError: invalid character in identifier

# %%
#11.Implement bitwise operators with examples.
#bitwise operators
a=5 #1001
b=10 #1100
print(a&b)#and
print(a|b)#or
print(-a)#not
print(a^b)#xor
print(a>>2)#right shift
print(a<<2)#left shift
# Out:
# 0
# 15
# -5
# 15
# 1
# 20

# %%
#12.Implement memebership operators with examples.
x="welcome"
print("w" in x)
y="python"
if("p" in y):
  print("present")
else:
  print("not present")
# Out:
# True
# present

# %%
#13.Implement identity operators with examples.
#identity operators
a=35
b=35
c="Bharath"
d="Bharat"
e=[12,23,34]
f=[12,23,34]
print(a is not b)
print(e is f)
print(c is d)
# Out:
#   File "<ipython-input-1-d11970abfe68>", line 11
#     print(c is d)
#                ^
# SyntaxError: invalid character in identifier

# %%
#14.Demonstrate negative indexeing for list and apply slicing.
list= [26,32,9,16,35,78,19,44,22]
print(list[::-1])
print(list[2:4])
print(list[2:7:5])
print(list[-3:-4:-2])
# Out:
# [22, 44, 19, 78, 35, 16, 9, 32, 26]
# [9, 16]
# [9]
# [19]

# %%
#15.Predict the output for the given code snippet and justify the result.
print('A series of character designated as one object known as a string'[::-1][4::3])
print('----------')
print('Welcome to python traing program'[3:10][::-1])
# Out:
# taawkcbe  tgerca  is
# ----------
# ot emoc

# %%
#16.Write a python program to get a desired output.
#input string is:
P_phrase="was it a car or a cat I saw"
print("the output string is:",P_phrase[::-1].upper())
# Out:
# the output string is: WAS I TAC A RO RAC A TI SAW
